# %% [markdown]
# # VISUALIZATION

# %%
import pandas as pd
from pandas_datareader import data

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### THE .PLOT() METHOD

# %% [markdown]
# #####IMPORTING "STOCKS" DATA FROM PANDAS DATAREADER

# %%
bac=data.DataReader(name="BAC",data_source= "iex",start="2014-07-01",end="2015-12-31")
bac.head(3)
# Out:
#                open     high      low    close    volume
# date
# 2014-07-01  14.3747  14.6271  14.3747  14.5803  74193538
# 2014-07-02  14.7486  14.9822  14.7299  14.8140  87685843
# 2014-07-03  15.0196  15.1692  14.9542  14.9822  70582291

# %%
bac.plot(y="high")

# %%
bac["close"].plot()

# %%
bac[["high","low"]].plot()
